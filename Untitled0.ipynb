# %% [markdown]
# <a href="https://colab.research.google.com/github/SaNight/WorkLikeAPythonDataEngineer/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# 載入 MNIST 數據集
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# 資料預處理
train_images = train_images.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1)).astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# 建立卷積神經網路模型
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# 編譯模型
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 訓練模型
model.fit(train_images, train_labels, epochs=5, batch_size=64, validation_split=0.2)

# 評估模型
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')

for i in range(5):
  # 選擇一個隨機的測試樣本
  index = np.random.randint(0, len(test_images))
  sample_image = test_images[index]
  sample_label = test_labels[index]

  # 顯示選擇的測試樣本
  plt.imshow(sample_image.reshape(28, 28), cmap='gray')
  plt.title(f"True Label: {np.argmax(sample_label)}")
  plt.show()

  # 將圖片輸入模型進行預測
  prediction = model.predict(np.expand_dims(sample_image, axis=0))
  predicted_label = np.argmax(prediction)

  # 顯示模型的預測結果
  plt.imshow(sample_image.reshape(28, 28), cmap='gray')
  plt.title(f"True Label: {np.argmax(sample_label)}\nPredicted Label: {predicted_label}")
  plt.show()
# Out:
# Epoch 1/5
# 750/750 [==============================] - 50s 64ms/step - loss: 0.2137 - accuracy: 0.9345 - val_loss: 0.0824 - val_accuracy: 0.9759
# Epoch 2/5
# 750/750 [==============================] - 45s 60ms/step - loss: 0.0581 - accuracy: 0.9817 - val_loss: 0.0502 - val_accuracy: 0.9852
# Epoch 3/5
# 750/750 [==============================] - 47s 63ms/step - loss: 0.0396 - accuracy: 0.9880 - val_loss: 0.0472 - val_accuracy: 0.9862
# Epoch 4/5
# 750/750 [==============================] - 47s 63ms/step - loss: 0.0332 - accuracy: 0.9896 - val_loss: 0.0437 - val_accuracy: 0.9872
# Epoch 5/5
# ...
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0315 - accuracy: 0.9906
# Test accuracy: 0.9905999898910522
# ...
# 1/1 [==============================] - 0s 33ms/step
